# %% [markdown]
# ## 3. Ungrouped data includes;

# %% [markdown]
# It involves the use of libraries i.e. numpy, pandas, matlpotlib and others to create statistical data

# %% [markdown]
# # libraries include
# import numpy as np
# import pandas as pd
# import matplotlib.pylot as plt

# %%
import pandas as pd
data = [23, 19, 20, 18, 22, 22, 23, 24, 28]
series = pd.Series(data)
ds = pd.Series(data)

# %%
ds =

# %% [markdown]
# ### Measures of Central Tendency.
# - Mean (Average)
# - Median (Middle value)
# - Mode (Most frequent)

# %% [markdown]
# ## Mean
# = summation of all x/ total number of x

# %%
mean_value = sum(data)/len(data)
mean_value
# Out:
# 22.11111111111111

# %%
import numpy as np
np.mean(data)
# Out:
# np.float64(22.11111111111111)

# %%
import pandas as pd
ds = pd.Series(data)

ds.mean()
# Out:
# np.float64(22.11111111111111)

# %% [markdown]
# ## Median

# %%
np.median(data)# numpy
# Out:
# np.float64(22.0)

# %%
ds.median() ## pandas
# Out:
# np.float64(22.0)

# %% [markdown]
# ## Mode

# %%
from statistics import mode

mode(data)
# Out:
# 23

# %%
from statistics import multimode
multimode(data)
# Out:
# [23, 22]

# %%
ds.mode()
# Out:
# 0    22
# 1    23
# dtype: int64

# %% [markdown]
# ### data representation
# >visually represent our data values

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(data, bins=6)
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.title("Histogram for ungrouped data")
plt.show()

# %% [markdown]
# # breifly about measures of central tendences.
# - The mean represents the average value of the dataset.
# - The median identifies the central value when the data is ordered.
# - The mode shows the most frequently occurring value.

# %%
# measures of dispersion
data = [23, 19, 20, 18, 22, 22, 23, 24, 28]
import numpy as np
import pandas as pd
range_value = max(data) - min(data)
variance_value = np.var(data, ddof=1) # sample variance
std_deviation_value = np.std(data, ddof=1) # sample standard deviation  

range_value, variance_value, std_deviation_value
# Out:
# (10, np.float64(8.86111111111111), np.float64(2.9767618499152917))

# %%
# or ds = pd.Series(data)
data = [23, 19, 20, 18, 22, 22, 23, 24, 28]
ds = pd.Series(data)
variance = ds.var()  # variance
std_deviation = ds.std()  # standard deviation      
range_value = ds.max() - ds.min()  # range

variance, std_deviation, range_value
# Out:
# (np.float64(8.86111111111111), np.float64(2.9767618499152917), np.int64(10))

# %%
# Visualisation.
import matplotlib.pyplot as plt
plt.hist(data, bins=6)
plt.title("Histogram for ungrouped data")
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.show()  
plt.figure()

# %% [markdown]
# # 4. Visualisation supports statistical data.

# %%
# histogram for ungrouped data
import matplotlib.pyplot as plt
plt.hist(data, bins=6)
plt.title("Histogram for ungrouped data")
plt.xlabel("Values")    
plt.ylabel("Frequencies")
plt.show()  
plt.figure()

# %%
# box plot
plt.figure()
plt.boxplot(data)
plt.title("Box plot for ungrouped data")
plt.ylabel("Values")
plt.show()

# %%
#line plot
plt.plot(data)
plt.title("Line plot for ungrouped data")
plt.xlabel("Index")
plt.ylabel("Values")
plt.show()
plt.figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3g/sx_l5_k10qn4c7vq5mb44v9c0000gn/T/ipykernel_6537/1746383541.py in <cell line: 0>()
#       1 #line plot
# ----> 2 plt.figure()
#       3 plt.plot(data)
#       4 plt.title("Line plot for ungrouped data")
#       5 plt.xlabel("Index")
#
# NameError: name 'plt' is not defined
