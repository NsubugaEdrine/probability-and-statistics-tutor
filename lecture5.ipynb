# %% [markdown]
# # PROBABILITY

# %%
sample_space_dice = {1,2,3,4,5,6}
sample_space_coin = {'tail','head'}

# %%
A = {2,4,6}
B = {3,5}
C = {'tail'}

# %%
prob_a = len(A)/len(sample_space_dice)
prob_a
# Out:
# 0.5

# %%
prob_b = len(B)/len(sample_space_dice)
prob_b
# Out:
# 0.3333333333333333

# %%
import pandas as pd

# %%
data = pd.read_csv('housing.csv')
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.shape
# Out:
# (545, 13)

# %%
dataset_sample_space = data.shape[0]
dataset_sample_space
# Out:
# 545

# %% [markdown]
# # EVENTS

# %%
data['mainroad']
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#       ...
# 540    yes
# 541     no
# 542    yes
# 543     no
# 544    yes
# Name: mainroad, Length: 545, dtype: str

# %%
main_road = data[data['mainroad']=='yes']
main_road
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 537   1890000  1700         3          1        2      yes        no       no
# 538   1890000  3649         2          1        1      yes        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# 542   1750000  3620         2          1        1      yes        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
main_road = data[data['mainroad']=='yes']
event_main_road = main_road.shape[0]
event_main_road
# Out:
# 468

# %%
prob = event_main_road/dataset_sample_space
prob
# Out:
# 0.8587155963302753

# %% [markdown]
# ## prob of choosing a house with more than 2 bedrooms

# %%
house_bedroom = data['bedrooms']
house_bedroom
# Out:
# 0      4
# 1      4
# 2      3
# 3      4
# 4      4
#       ..
# 540    2
# 541    3
# 542    2
# 543    3
# 544    3
# Name: bedrooms, Length: 545, dtype: int64

# %%
house = data[data['bedrooms']>2]
house
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 536   1960000  3420         5          1        2       no        no       no
# 537   1890000  1700         3          1        2      yes        no       no
# 541   1767150  2400         3          1        1       no        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
Event_bedrooms = house.shape[0]
Event_bedrooms
# Out:
# 407

# %%
prob_bed = Event_bedrooms/dataset_sample_space
prob_bed
# Out:
# 0.7467889908256881

# %%
prob = Event_bedrooms/dataset_sample_space
print(f"{prob:.3}")
# Out:
# 0.747

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numerical_df = data.select_dtypes(include=['float64', 'int64'])
numerical_df
# Out:
#         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]

# %%
meanvalues = numerical_df.mean()
meanvalues
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
numerical_df.corr
# Out:
# <bound method DataFrame.corr of         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]>

# %%
plt.Figure(figsize=(6,6))
sns.heatmap(numerical_df.corr(), annot=True, Cmap = "coolwarm")
plt.title("Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3g/sx_l5_k10qn4c7vq5mb44v9c0000gn/T/ipykernel_7403/2451889896.py in <cell line: 0>()
#       1 plt.Figure(figsize=(6,6))
# ----> 2 sns.heatmap(numerical_df.corr(), annot=True, Cmap = "coolwarm")
#       3 plt.title("Heatmap")
#       4 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457     if square:
#     458         ax.set_aspect("equal")
# --> 459     plotter.plot(ax, cbar_ax, kwargs)
#     460     return ax
#     461
#
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     304
# ...

# %%
data = {
    "X": [2,3,4,5,6]
    "Y": [6,10,45,6,8]
}

df.pdDataFrame(data)
df.corr(method = "pearson")
