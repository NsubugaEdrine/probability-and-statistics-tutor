# %% [markdown]
# # Load the Packages

# %%
import pandas as pd

# %% [markdown]
# # Loading datasets
# 1. extensions(.xlsx, .csv, .json, .parquet)
# 2. know where the file is stored.

# %%
housing = pd.read_csv('housing.csv')

# %%
housing.head()

# %%
housing.tail()
