# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vg_sales = pd.read_csv('vgsales.csv')
vg_sales

# %%
vg_sales.head()

# %%
vg_sales.tail()

# %%
vg_sales.shape

# %%
vg_sales.shape[0]

# %%
vg_sales.shape[1]

# %%
vg_sales.info()

# %%
vg_sales.describe()

# %%
vg_sales.values

# %%
vg_sales.columns

# %%
vg_sales['JP_Sales']  ## or vg_sales["JP_Sales"].unique

# %%
vg_sales["JP_Sales"].mean()

# %%
vg_sales["JP_Sales"].median()

# %%
vg_sales["JP_Sales"].mode()

# %%
max_price = vg_sales["JP_Sales"].max()
max_price
